# %%
import cv2
import os

# %%
def get_video_fps(video_path):
    """
    Calculate and return the FPS (frames per second) of a video.

    Args:
    - video_path (str): Path to the video file.

    Returns:
    - fps (float): Frames per second of the video.
    """
    # Load video
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return None

    # Get frames per second
    fps = cap.get(cv2.CAP_PROP_FPS)
    cap.release()
    return fps

# %%
# Usage example
video_path = r"D:\Boxing dataset\Dmitry Bivol - Excellent Jab & Distance Control.mp4"  # Replace with your video path
fps = get_video_fps(video_path)
if fps:
    print(f"The FPS of the video is: {fps}")
# Out:
# The FPS of the video is: 30.0

# %%
def extract_frames_per_second(video_path, output_folder, frames_per_second=3):
    """
    Extract a specified number of frames per second from a video and save them as images.

    Args:
    - video_path (str): Path to the video file.
    - output_folder (str): Folder to save the extracted frames.
    - frames_per_second (int): Number of frames to save per second. Default is 2.
    """

    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Load video
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    # Get the frame rate of the video
    fps = cap.get(cv2.CAP_PROP_FPS)
    interval = int(fps // frames_per_second)  # Interval between frames to capture

    frame_count = 0
    saved_count = 0

    while cap.isOpened():
        # Read frame-by-frame
        ret, frame = cap.read()
        if not ret:
            break

        # Save frame if it matches the interval for frames per second
        if frame_count % interval == 20:
            frame_filename = os.path.join(output_folder, f"frame_{saved_count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            saved_count += 1
            print(f"Saved {frame_filename}")

        frame_count += 1

    # Release video capture
    cap.release()
    print(f"Total frames saved: {saved_count}")

# %%
def extract_frames(video_path, output_folder, interval=1):
    """
    Extract frames from a video at a specified interval and save them as images.

    Args:
    - video_path (str): Path to the video file.
    - output_folder (str): Folder to save the extracted frames.
    - interval (int): Interval (in frames) at which to save images. Default is 30.
    """

    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Load video
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    frame_count = 0
    saved_count = 0

    while cap.isOpened():
        # Read frame-by-frame
        ret, frame = cap.read()
        if not ret:
            break

        # Save frame if it matches the interval
        if frame_count % interval == 0:
            frame_filename = os.path.join(output_folder, f"frame_{saved_count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            saved_count += 1
            print(f"Saved {frame_filename}")

        frame_count += 1

    # Release video capture
    cap.release()
    print(f"Total frames saved: {saved_count}")

# %%
def check_file_access(video_path):
    if os.path.exists(video_path):
        if os.access(video_path, os.R_OK):
            print("File exists and is readable.")
            return True
        else:
            print("File exists but is not readable.")
            return False
    else:
        print("File does not exist.")
        return False

# %%
# Usage example
video_path = r"D:\Boxing dataset\Golovkin's Masterful Jab _ Boxing Technique and Fight Breakdown _ Film Study.mp4"  # Replace with your video path
output_folder = r"D:\Boxing dataset\test_frame"
#extract_all_frames(video_path, output_folder)
extract_frames(video_path, output_folder)
#check_file_access(video_path)
# Out:
# Saved D:\Boxing dataset\test_frame\frame_0000.jpg
# Saved D:\Boxing dataset\test_frame\frame_0001.jpg
# Saved D:\Boxing dataset\test_frame\frame_0002.jpg
# Saved D:\Boxing dataset\test_frame\frame_0003.jpg
# Saved D:\Boxing dataset\test_frame\frame_0004.jpg
# Saved D:\Boxing dataset\test_frame\frame_0005.jpg
# Saved D:\Boxing dataset\test_frame\frame_0006.jpg
# Saved D:\Boxing dataset\test_frame\frame_0007.jpg
# Saved D:\Boxing dataset\test_frame\frame_0008.jpg
# Saved D:\Boxing dataset\test_frame\frame_0009.jpg
# Saved D:\Boxing dataset\test_frame\frame_0010.jpg
# Saved D:\Boxing dataset\test_frame\frame_0011.jpg
# Saved D:\Boxing dataset\test_frame\frame_0012.jpg
# Saved D:\Boxing dataset\test_frame\frame_0013.jpg
# Saved D:\Boxing dataset\test_frame\frame_0014.jpg
# Saved D:\Boxing dataset\test_frame\frame_0015.jpg
# Saved D:\Boxing dataset\test_frame\frame_0016.jpg
# Saved D:\Boxing dataset\test_frame\frame_0017.jpg
# Saved D:\Boxing dataset\test_frame\frame_0018.jpg
# Saved D:\Boxing dataset\test_frame\frame_0019.jpg
# Saved D:\Boxing dataset\test_frame\frame_0020.jpg
# Saved D:\Boxing dataset\test_frame\frame_0021.jpg
# Saved D:\Boxing dataset\test_frame\frame_0022.jpg
# Saved D:\Boxing dataset\test_frame\frame_0023.jpg
# Saved D:\Boxing dataset\test_frame\frame_0024.jpg
# Saved D:\Boxing dataset\test_frame\frame_0025.jpg
# Saved D:\Boxing dataset\test_frame\frame_0026.jpg
# Saved D:\Boxing dataset\test_frame\frame_0027.jpg
# Saved D:\Boxing dataset\test_frame\frame_0028.jpg
# Saved D:\Boxing dataset\test_frame\frame_0029.jpg
# Saved D:\Boxing dataset\test_frame\frame_0030.jpg
# Saved D:\Boxing dataset\test_frame\frame_0031.jpg
# Saved D:\Boxing dataset\test_frame\frame_0032.jpg
# Saved D:\Boxing dataset\test_frame\frame_0033.jpg
# Saved D:\Boxing dataset\test_frame\frame_0034.jpg
# Saved D:\Boxing dataset\test_frame\frame_0035.jpg
# Saved D:\Boxing dataset\test_frame\frame_0036.jpg
# Saved D:\Boxing dataset\test_frame\frame_0037.jpg
# Saved D:\Boxing dataset\test_frame\frame_0038.jpg
# Saved D:\Boxing dataset\test_frame\frame_0039.jpg
# Saved D:\Boxing dataset\test_frame\frame_0040.jpg
# Saved D:\Boxing dataset\test_frame\frame_0041.jpg
# Saved D:\Boxing dataset\test_frame\frame_0042.jpg
# Saved D:\Boxing dataset\test_frame\frame_0043.jpg
# Saved D:\Boxing dataset\test_frame\frame_0044.jpg
# Saved D:\Boxing dataset\test_frame\frame_0045.jpg
# Saved D:\Boxing dataset\test_frame\frame_0046.jpg
# Saved D:\Boxing dataset\test_frame\frame_0047.jpg
# Saved D:\Boxing dataset\test_frame\frame_0048.jpg
# Saved D:\Boxing dataset\test_frame\frame_0049.jpg
# Saved D:\Boxing dataset\test_frame\frame_0050.jpg
# Saved D:\Boxing dataset\test_frame\frame_0051.jpg
# Saved D:\Boxing dataset\test_frame\frame_0052.jpg
# Saved D:\Boxing dataset\test_frame\frame_0053.jpg
# Saved D:\Boxing dataset\test_frame\frame_0054.jpg
# Saved D:\Boxing dataset\test_frame\frame_0055.jpg
# Saved D:\Boxing dataset\test_frame\frame_0056.jpg
# Saved D:\Boxing dataset\test_frame\frame_0057.jpg
# Saved D:\Boxing dataset\test_frame\frame_0058.jpg
# Saved D:\Boxing dataset\test_frame\frame_0059.jpg
# Saved D:\Boxing dataset\test_frame\frame_0060.jpg
# Saved D:\Boxing dataset\test_frame\frame_0061.jpg
# Saved D:\Boxing dataset\test_frame\frame_0062.jpg
# Saved D:\Boxing dataset\test_frame\frame_0063.jpg
# Saved D:\Boxing dataset\test_frame\frame_0064.jpg
# Saved D:\Boxing dataset\test_frame\frame_0065.jpg
# Saved D:\Boxing dataset\test_frame\frame_0066.jpg
# Saved D:\Boxing dataset\test_frame\frame_0067.jpg
# Saved D:\Boxing dataset\test_frame\frame_0068.jpg
# Saved D:\Boxing dataset\test_frame\frame_0069.jpg
# Saved D:\Boxing dataset\test_frame\frame_0070.jpg
# Saved D:\Boxing dataset\test_frame\frame_0071.jpg
# Saved D:\Boxing dataset\test_frame\frame_0072.jpg
# Saved D:\Boxing dataset\test_frame\frame_0073.jpg
# Saved D:\Boxing dataset\test_frame\frame_0074.jpg
# Saved D:\Boxing dataset\test_frame\frame_0075.jpg
# Saved D:\Boxing dataset\test_frame\frame_0076.jpg
# Saved D:\Boxing dataset\test_frame\frame_0077.jpg
# Saved D:\Boxing dataset\test_frame\frame_0078.jpg
# Saved D:\Boxing dataset\test_frame\frame_0079.jpg
# Saved D:\Boxing dataset\test_frame\frame_0080.jpg
# Saved D:\Boxing dataset\test_frame\frame_0081.jpg
# Saved D:\Boxing dataset\test_frame\frame_0082.jpg
# Saved D:\Boxing dataset\test_frame\frame_0083.jpg
# Saved D:\Boxing dataset\test_frame\frame_0084.jpg
# Saved D:\Boxing dataset\test_frame\frame_0085.jpg
# Saved D:\Boxing dataset\test_frame\frame_0086.jpg
# Saved D:\Boxing dataset\test_frame\frame_0087.jpg
# Saved D:\Boxing dataset\test_frame\frame_0088.jpg
# Saved D:\Boxing dataset\test_frame\frame_0089.jpg
# Saved D:\Boxing dataset\test_frame\frame_0090.jpg
# Saved D:\Boxing dataset\test_frame\frame_0091.jpg
# Saved D:\Boxing dataset\test_frame\frame_0092.jpg
# Saved D:\Boxing dataset\test_frame\frame_0093.jpg
# Saved D:\Boxing dataset\test_frame\frame_0094.jpg
# Saved D:\Boxing dataset\test_frame\frame_0095.jpg
# Saved D:\Boxing dataset\test_frame\frame_0096.jpg
# Saved D:\Boxing dataset\test_frame\frame_0097.jpg
# Saved D:\Boxing dataset\test_frame\frame_0098.jpg
# Saved D:\Boxing dataset\test_frame\frame_0099.jpg
# Saved D:\Boxing dataset\test_frame\frame_0100.jpg
# Saved D:\Boxing dataset\test_frame\frame_0101.jpg
# Saved D:\Boxing dataset\test_frame\frame_0102.jpg
# Saved D:\Boxing dataset\test_frame\frame_0103.jpg
# Saved D:\Boxing dataset\test_frame\frame_0104.jpg
# Saved D:\Boxing dataset\test_frame\frame_0105.jpg
# Saved D:\Boxing dataset\test_frame\frame_0106.jpg
# Saved D:\Boxing dataset\test_frame\frame_0107.jpg
# Saved D:\Boxing dataset\test_frame\frame_0108.jpg
# Saved D:\Boxing dataset\test_frame\frame_0109.jpg
# Saved D:\Boxing dataset\test_frame\frame_0110.jpg
# Saved D:\Boxing dataset\test_frame\frame_0111.jpg
# Saved D:\Boxing dataset\test_frame\frame_0112.jpg
# Saved D:\Boxing dataset\test_frame\frame_0113.jpg
# Saved D:\Boxing dataset\test_frame\frame_0114.jpg
# Saved D:\Boxing dataset\test_frame\frame_0115.jpg
# Saved D:\Boxing dataset\test_frame\frame_0116.jpg
# Saved D:\Boxing dataset\test_frame\frame_0117.jpg
# Saved D:\Boxing dataset\test_frame\frame_0118.jpg
# Saved D:\Boxing dataset\test_frame\frame_0119.jpg
# Saved D:\Boxing dataset\test_frame\frame_0120.jpg
# Saved D:\Boxing dataset\test_frame\frame_0121.jpg
# Saved D:\Boxing dataset\test_frame\frame_0122.jpg
# Saved D:\Boxing dataset\test_frame\frame_0123.jpg
# Saved D:\Boxing dataset\test_frame\frame_0124.jpg
# Saved D:\Boxing dataset\test_frame\frame_0125.jpg
# Saved D:\Boxing dataset\test_frame\frame_0126.jpg
# Saved D:\Boxing dataset\test_frame\frame_0127.jpg
# Saved D:\Boxing dataset\test_frame\frame_0128.jpg
# Saved D:\Boxing dataset\test_frame\frame_0129.jpg
# Saved D:\Boxing dataset\test_frame\frame_0130.jpg
# Saved D:\Boxing dataset\test_frame\frame_0131.jpg
# Saved D:\Boxing dataset\test_frame\frame_0132.jpg
# Saved D:\Boxing dataset\test_frame\frame_0133.jpg
# Saved D:\Boxing dataset\test_frame\frame_0134.jpg
# Saved D:\Boxing dataset\test_frame\frame_0135.jpg
# Saved D:\Boxing dataset\test_frame\frame_0136.jpg
# Saved D:\Boxing dataset\test_frame\frame_0137.jpg
# Saved D:\Boxing dataset\test_frame\frame_0138.jpg
# Saved D:\Boxing dataset\test_frame\frame_0139.jpg
# Saved D:\Boxing dataset\test_frame\frame_0140.jpg
# Saved D:\Boxing dataset\test_frame\frame_0141.jpg
# Saved D:\Boxing dataset\test_frame\frame_0142.jpg
# Saved D:\Boxing dataset\test_frame\frame_0143.jpg
# Saved D:\Boxing dataset\test_frame\frame_0144.jpg
# Saved D:\Boxing dataset\test_frame\frame_0145.jpg
# Saved D:\Boxing dataset\test_frame\frame_0146.jpg
# Saved D:\Boxing dataset\test_frame\frame_0147.jpg
# Saved D:\Boxing dataset\test_frame\frame_0148.jpg
# Saved D:\Boxing dataset\test_frame\frame_0149.jpg
# Saved D:\Boxing dataset\test_frame\frame_0150.jpg
# Saved D:\Boxing dataset\test_frame\frame_0151.jpg
# Saved D:\Boxing dataset\test_frame\frame_0152.jpg
# Saved D:\Boxing dataset\test_frame\frame_0153.jpg
# Saved D:\Boxing dataset\test_frame\frame_0154.jpg
# Saved D:\Boxing dataset\test_frame\frame_0155.jpg
# Saved D:\Boxing dataset\test_frame\frame_0156.jpg
# Saved D:\Boxing dataset\test_frame\frame_0157.jpg
# Saved D:\Boxing dataset\test_frame\frame_0158.jpg
# Saved D:\Boxing dataset\test_frame\frame_0159.jpg
# Saved D:\Boxing dataset\test_frame\frame_0160.jpg
# Saved D:\Boxing dataset\test_frame\frame_0161.jpg
# Saved D:\Boxing dataset\test_frame\frame_0162.jpg
# Saved D:\Boxing dataset\test_frame\frame_0163.jpg
# Saved D:\Boxing dataset\test_frame\frame_0164.jpg
# Saved D:\Boxing dataset\test_frame\frame_0165.jpg
# Saved D:\Boxing dataset\test_frame\frame_0166.jpg
# Saved D:\Boxing dataset\test_frame\frame_0167.jpg
# Saved D:\Boxing dataset\test_frame\frame_0168.jpg
# Saved D:\Boxing dataset\test_frame\frame_0169.jpg
# Saved D:\Boxing dataset\test_frame\frame_0170.jpg
# Saved D:\Boxing dataset\test_frame\frame_0171.jpg
# Saved D:\Boxing dataset\test_frame\frame_0172.jpg
# Saved D:\Boxing dataset\test_frame\frame_0173.jpg
# Saved D:\Boxing dataset\test_frame\frame_0174.jpg
# Saved D:\Boxing dataset\test_frame\frame_0175.jpg
# Saved D:\Boxing dataset\test_frame\frame_0176.jpg
# Saved D:\Boxing dataset\test_frame\frame_0177.jpg
# Saved D:\Boxing dataset\test_frame\frame_0178.jpg
# Saved D:\Boxing dataset\test_frame\frame_0179.jpg
# Saved D:\Boxing dataset\test_frame\frame_0180.jpg
# Saved D:\Boxing dataset\test_frame\frame_0181.jpg
# Saved D:\Boxing dataset\test_frame\frame_0182.jpg
# Saved D:\Boxing dataset\test_frame\frame_0183.jpg
# Saved D:\Boxing dataset\test_frame\frame_0184.jpg
# Saved D:\Boxing dataset\test_frame\frame_0185.jpg
# Saved D:\Boxing dataset\test_frame\frame_0186.jpg
# Saved D:\Boxing dataset\test_frame\frame_0187.jpg
# Saved D:\Boxing dataset\test_frame\frame_0188.jpg
# Saved D:\Boxing dataset\test_frame\frame_0189.jpg
# Saved D:\Boxing dataset\test_frame\frame_0190.jpg
# Saved D:\Boxing dataset\test_frame\frame_0191.jpg
# Saved D:\Boxing dataset\test_frame\frame_0192.jpg
# Saved D:\Boxing dataset\test_frame\frame_0193.jpg
# Saved D:\Boxing dataset\test_frame\frame_0194.jpg
# Saved D:\Boxing dataset\test_frame\frame_0195.jpg
# Saved D:\Boxing dataset\test_frame\frame_0196.jpg
# Saved D:\Boxing dataset\test_frame\frame_0197.jpg
# Saved D:\Boxing dataset\test_frame\frame_0198.jpg
# Saved D:\Boxing dataset\test_frame\frame_0199.jpg
# Saved D:\Boxing dataset\test_frame\frame_0200.jpg
# Saved D:\Boxing dataset\test_frame\frame_0201.jpg
# Saved D:\Boxing dataset\test_frame\frame_0202.jpg
# Saved D:\Boxing dataset\test_frame\frame_0203.jpg
# Saved D:\Boxing dataset\test_frame\frame_0204.jpg
# Saved D:\Boxing dataset\test_frame\frame_0205.jpg
# Saved D:\Boxing dataset\test_frame\frame_0206.jpg
# Saved D:\Boxing dataset\test_frame\frame_0207.jpg
# Saved D:\Boxing dataset\test_frame\frame_0208.jpg
# Saved D:\Boxing dataset\test_frame\frame_0209.jpg
# Saved D:\Boxing dataset\test_frame\frame_0210.jpg
# Saved D:\Boxing dataset\test_frame\frame_0211.jpg
# Saved D:\Boxing dataset\test_frame\frame_0212.jpg
# Saved D:\Boxing dataset\test_frame\frame_0213.jpg
# Saved D:\Boxing dataset\test_frame\frame_0214.jpg
# Saved D:\Boxing dataset\test_frame\frame_0215.jpg
# Saved D:\Boxing dataset\test_frame\frame_0216.jpg
# Saved D:\Boxing dataset\test_frame\frame_0217.jpg
# Saved D:\Boxing dataset\test_frame\frame_0218.jpg
# Saved D:\Boxing dataset\test_frame\frame_0219.jpg
# Saved D:\Boxing dataset\test_frame\frame_0220.jpg
# Saved D:\Boxing dataset\test_frame\frame_0221.jpg
# Saved D:\Boxing dataset\test_frame\frame_0222.jpg
# Saved D:\Boxing dataset\test_frame\frame_0223.jpg
# Saved D:\Boxing dataset\test_frame\frame_0224.jpg
# Saved D:\Boxing dataset\test_frame\frame_0225.jpg
# Saved D:\Boxing dataset\test_frame\frame_0226.jpg
# Saved D:\Boxing dataset\test_frame\frame_0227.jpg
# Saved D:\Boxing dataset\test_frame\frame_0228.jpg
# Saved D:\Boxing dataset\test_frame\frame_0229.jpg
# Saved D:\Boxing dataset\test_frame\frame_0230.jpg
# Saved D:\Boxing dataset\test_frame\frame_0231.jpg
# Saved D:\Boxing dataset\test_frame\frame_0232.jpg
# Saved D:\Boxing dataset\test_frame\frame_0233.jpg
# Saved D:\Boxing dataset\test_frame\frame_0234.jpg
# Saved D:\Boxing dataset\test_frame\frame_0235.jpg
# Saved D:\Boxing dataset\test_frame\frame_0236.jpg
# Saved D:\Boxing dataset\test_frame\frame_0237.jpg
# Saved D:\Boxing dataset\test_frame\frame_0238.jpg
# Saved D:\Boxing dataset\test_frame\frame_0239.jpg
# Saved D:\Boxing dataset\test_frame\frame_0240.jpg
# Saved D:\Boxing dataset\test_frame\frame_0241.jpg
# Saved D:\Boxing dataset\test_frame\frame_0242.jpg
# Saved D:\Boxing dataset\test_frame\frame_0243.jpg
# Saved D:\Boxing dataset\test_frame\frame_0244.jpg
# Saved D:\Boxing dataset\test_frame\frame_0245.jpg
# Saved D:\Boxing dataset\test_frame\frame_0246.jpg
# Saved D:\Boxing dataset\test_frame\frame_0247.jpg
# Saved D:\Boxing dataset\test_frame\frame_0248.jpg
# Saved D:\Boxing dataset\test_frame\frame_0249.jpg
# Saved D:\Boxing dataset\test_frame\frame_0250.jpg
# Saved D:\Boxing dataset\test_frame\frame_0251.jpg
# Saved D:\Boxing dataset\test_frame\frame_0252.jpg
# Saved D:\Boxing dataset\test_frame\frame_0253.jpg
# Saved D:\Boxing dataset\test_frame\frame_0254.jpg
# Saved D:\Boxing dataset\test_frame\frame_0255.jpg
# Saved D:\Boxing dataset\test_frame\frame_0256.jpg
# Saved D:\Boxing dataset\test_frame\frame_0257.jpg
# Saved D:\Boxing dataset\test_frame\frame_0258.jpg
# Saved D:\Boxing dataset\test_frame\frame_0259.jpg
# Saved D:\Boxing dataset\test_frame\frame_0260.jpg
# Saved D:\Boxing dataset\test_frame\frame_0261.jpg
# Saved D:\Boxing dataset\test_frame\frame_0262.jpg
# Saved D:\Boxing dataset\test_frame\frame_0263.jpg
# Saved D:\Boxing dataset\test_frame\frame_0264.jpg
# Saved D:\Boxing dataset\test_frame\frame_0265.jpg
# Saved D:\Boxing dataset\test_frame\frame_0266.jpg
# Saved D:\Boxing dataset\test_frame\frame_0267.jpg
# Saved D:\Boxing dataset\test_frame\frame_0268.jpg
# Saved D:\Boxing dataset\test_frame\frame_0269.jpg
# Saved D:\Boxing dataset\test_frame\frame_0270.jpg
# Saved D:\Boxing dataset\test_frame\frame_0271.jpg
# Saved D:\Boxing dataset\test_frame\frame_0272.jpg
# Saved D:\Boxing dataset\test_frame\frame_0273.jpg
# Saved D:\Boxing dataset\test_frame\frame_0274.jpg
# Saved D:\Boxing dataset\test_frame\frame_0275.jpg
# Saved D:\Boxing dataset\test_frame\frame_0276.jpg
# Saved D:\Boxing dataset\test_frame\frame_0277.jpg
# Saved D:\Boxing dataset\test_frame\frame_0278.jpg
# Saved D:\Boxing dataset\test_frame\frame_0279.jpg
# Saved D:\Boxing dataset\test_frame\frame_0280.jpg
# Saved D:\Boxing dataset\test_frame\frame_0281.jpg
# Saved D:\Boxing dataset\test_frame\frame_0282.jpg
# Saved D:\Boxing dataset\test_frame\frame_0283.jpg
# Saved D:\Boxing dataset\test_frame\frame_0284.jpg
# Saved D:\Boxing dataset\test_frame\frame_0285.jpg
# Saved D:\Boxing dataset\test_frame\frame_0286.jpg
# Saved D:\Boxing dataset\test_frame\frame_0287.jpg
# Saved D:\Boxing dataset\test_frame\frame_0288.jpg
# Saved D:\Boxing dataset\test_frame\frame_0289.jpg
# Saved D:\Boxing dataset\test_frame\frame_0290.jpg
# Saved D:\Boxing dataset\test_frame\frame_0291.jpg
# Saved D:\Boxing dataset\test_frame\frame_0292.jpg
# Saved D:\Boxing dataset\test_frame\frame_0293.jpg
# Saved D:\Boxing dataset\test_frame\frame_0294.jpg
# Saved D:\Boxing dataset\test_frame\frame_0295.jpg
# Saved D:\Boxing dataset\test_frame\frame_0296.jpg
# Saved D:\Boxing dataset\test_frame\frame_0297.jpg
# Saved D:\Boxing dataset\test_frame\frame_0298.jpg
# Saved D:\Boxing dataset\test_frame\frame_0299.jpg
# Saved D:\Boxing dataset\test_frame\frame_0300.jpg
# Saved D:\Boxing dataset\test_frame\frame_0301.jpg
# Saved D:\Boxing dataset\test_frame\frame_0302.jpg
# Saved D:\Boxing dataset\test_frame\frame_0303.jpg
# Saved D:\Boxing dataset\test_frame\frame_0304.jpg
# Saved D:\Boxing dataset\test_frame\frame_0305.jpg
# Saved D:\Boxing dataset\test_frame\frame_0306.jpg
# Saved D:\Boxing dataset\test_frame\frame_0307.jpg
# Saved D:\Boxing dataset\test_frame\frame_0308.jpg
# Saved D:\Boxing dataset\test_frame\frame_0309.jpg
# Saved D:\Boxing dataset\test_frame\frame_0310.jpg
# Saved D:\Boxing dataset\test_frame\frame_0311.jpg
# Saved D:\Boxing dataset\test_frame\frame_0312.jpg
# Saved D:\Boxing dataset\test_frame\frame_0313.jpg
# Saved D:\Boxing dataset\test_frame\frame_0314.jpg
# Saved D:\Boxing dataset\test_frame\frame_0315.jpg
# Saved D:\Boxing dataset\test_frame\frame_0316.jpg
# Saved D:\Boxing dataset\test_frame\frame_0317.jpg
# Saved D:\Boxing dataset\test_frame\frame_0318.jpg
# Saved D:\Boxing dataset\test_frame\frame_0319.jpg
# Saved D:\Boxing dataset\test_frame\frame_0320.jpg
# Saved D:\Boxing dataset\test_frame\frame_0321.jpg
# Saved D:\Boxing dataset\test_frame\frame_0322.jpg
# Saved D:\Boxing dataset\test_frame\frame_0323.jpg
# Saved D:\Boxing dataset\test_frame\frame_0324.jpg
# Saved D:\Boxing dataset\test_frame\frame_0325.jpg
# Saved D:\Boxing dataset\test_frame\frame_0326.jpg
# Saved D:\Boxing dataset\test_frame\frame_0327.jpg
# Saved D:\Boxing dataset\test_frame\frame_0328.jpg
# Saved D:\Boxing dataset\test_frame\frame_0329.jpg
# Saved D:\Boxing dataset\test_frame\frame_0330.jpg
# Saved D:\Boxing dataset\test_frame\frame_0331.jpg
# Saved D:\Boxing dataset\test_frame\frame_0332.jpg
# Saved D:\Boxing dataset\test_frame\frame_0333.jpg
# Saved D:\Boxing dataset\test_frame\frame_0334.jpg
# Saved D:\Boxing dataset\test_frame\frame_0335.jpg
# Saved D:\Boxing dataset\test_frame\frame_0336.jpg
# Saved D:\Boxing dataset\test_frame\frame_0337.jpg
# Saved D:\Boxing dataset\test_frame\frame_0338.jpg
# Saved D:\Boxing dataset\test_frame\frame_0339.jpg
# Saved D:\Boxing dataset\test_frame\frame_0340.jpg
# Saved D:\Boxing dataset\test_frame\frame_0341.jpg
# Saved D:\Boxing dataset\test_frame\frame_0342.jpg
# Saved D:\Boxing dataset\test_frame\frame_0343.jpg
# Saved D:\Boxing dataset\test_frame\frame_0344.jpg
# Saved D:\Boxing dataset\test_frame\frame_0345.jpg
# Saved D:\Boxing dataset\test_frame\frame_0346.jpg
# Saved D:\Boxing dataset\test_frame\frame_0347.jpg
# Saved D:\Boxing dataset\test_frame\frame_0348.jpg
# Saved D:\Boxing dataset\test_frame\frame_0349.jpg
# Saved D:\Boxing dataset\test_frame\frame_0350.jpg
# Saved D:\Boxing dataset\test_frame\frame_0351.jpg
# Saved D:\Boxing dataset\test_frame\frame_0352.jpg
# Saved D:\Boxing dataset\test_frame\frame_0353.jpg
# Saved D:\Boxing dataset\test_frame\frame_0354.jpg
# Saved D:\Boxing dataset\test_frame\frame_0355.jpg
# Saved D:\Boxing dataset\test_frame\frame_0356.jpg
# Saved D:\Boxing dataset\test_frame\frame_0357.jpg
# Saved D:\Boxing dataset\test_frame\frame_0358.jpg
# Saved D:\Boxing dataset\test_frame\frame_0359.jpg
# Saved D:\Boxing dataset\test_frame\frame_0360.jpg
# Saved D:\Boxing dataset\test_frame\frame_0361.jpg
# Saved D:\Boxing dataset\test_frame\frame_0362.jpg
# Saved D:\Boxing dataset\test_frame\frame_0363.jpg
# Saved D:\Boxing dataset\test_frame\frame_0364.jpg
# Saved D:\Boxing dataset\test_frame\frame_0365.jpg
# Saved D:\Boxing dataset\test_frame\frame_0366.jpg
# Saved D:\Boxing dataset\test_frame\frame_0367.jpg
# Saved D:\Boxing dataset\test_frame\frame_0368.jpg
# Saved D:\Boxing dataset\test_frame\frame_0369.jpg
# Saved D:\Boxing dataset\test_frame\frame_0370.jpg
# Saved D:\Boxing dataset\test_frame\frame_0371.jpg
# Saved D:\Boxing dataset\test_frame\frame_0372.jpg
# Saved D:\Boxing dataset\test_frame\frame_0373.jpg
# Saved D:\Boxing dataset\test_frame\frame_0374.jpg
# Saved D:\Boxing dataset\test_frame\frame_0375.jpg
# Saved D:\Boxing dataset\test_frame\frame_0376.jpg
# Saved D:\Boxing dataset\test_frame\frame_0377.jpg
# Saved D:\Boxing dataset\test_frame\frame_0378.jpg
# Saved D:\Boxing dataset\test_frame\frame_0379.jpg
# Saved D:\Boxing dataset\test_frame\frame_0380.jpg
# Saved D:\Boxing dataset\test_frame\frame_0381.jpg
# Saved D:\Boxing dataset\test_frame\frame_0382.jpg
# Saved D:\Boxing dataset\test_frame\frame_0383.jpg
# Saved D:\Boxing dataset\test_frame\frame_0384.jpg
# Saved D:\Boxing dataset\test_frame\frame_0385.jpg
# Saved D:\Boxing dataset\test_frame\frame_0386.jpg
# Saved D:\Boxing dataset\test_frame\frame_0387.jpg
# Saved D:\Boxing dataset\test_frame\frame_0388.jpg
# Saved D:\Boxing dataset\test_frame\frame_0389.jpg
# Saved D:\Boxing dataset\test_frame\frame_0390.jpg
# Saved D:\Boxing dataset\test_frame\frame_0391.jpg
# Saved D:\Boxing dataset\test_frame\frame_0392.jpg
# Saved D:\Boxing dataset\test_frame\frame_0393.jpg
# Saved D:\Boxing dataset\test_frame\frame_0394.jpg
# Saved D:\Boxing dataset\test_frame\frame_0395.jpg
# Saved D:\Boxing dataset\test_frame\frame_0396.jpg
# Saved D:\Boxing dataset\test_frame\frame_0397.jpg
# Saved D:\Boxing dataset\test_frame\frame_0398.jpg
# Saved D:\Boxing dataset\test_frame\frame_0399.jpg
# Saved D:\Boxing dataset\test_frame\frame_0400.jpg
# Saved D:\Boxing dataset\test_frame\frame_0401.jpg
# Saved D:\Boxing dataset\test_frame\frame_0402.jpg
# Saved D:\Boxing dataset\test_frame\frame_0403.jpg
# Saved D:\Boxing dataset\test_frame\frame_0404.jpg
# Saved D:\Boxing dataset\test_frame\frame_0405.jpg
# Saved D:\Boxing dataset\test_frame\frame_0406.jpg
# Saved D:\Boxing dataset\test_frame\frame_0407.jpg
# Saved D:\Boxing dataset\test_frame\frame_0408.jpg
# Saved D:\Boxing dataset\test_frame\frame_0409.jpg
# Saved D:\Boxing dataset\test_frame\frame_0410.jpg
# Saved D:\Boxing dataset\test_frame\frame_0411.jpg
# Saved D:\Boxing dataset\test_frame\frame_0412.jpg
# Saved D:\Boxing dataset\test_frame\frame_0413.jpg
# Saved D:\Boxing dataset\test_frame\frame_0414.jpg
# Saved D:\Boxing dataset\test_frame\frame_0415.jpg
# Saved D:\Boxing dataset\test_frame\frame_0416.jpg
# Saved D:\Boxing dataset\test_frame\frame_0417.jpg
# Saved D:\Boxing dataset\test_frame\frame_0418.jpg
# Saved D:\Boxing dataset\test_frame\frame_0419.jpg
# Saved D:\Boxing dataset\test_frame\frame_0420.jpg
# Saved D:\Boxing dataset\test_frame\frame_0421.jpg
# Saved D:\Boxing dataset\test_frame\frame_0422.jpg
# Saved D:\Boxing dataset\test_frame\frame_0423.jpg
# Saved D:\Boxing dataset\test_frame\frame_0424.jpg
# Saved D:\Boxing dataset\test_frame\frame_0425.jpg
# Saved D:\Boxing dataset\test_frame\frame_0426.jpg
# Saved D:\Boxing dataset\test_frame\frame_0427.jpg
# Saved D:\Boxing dataset\test_frame\frame_0428.jpg
# Saved D:\Boxing dataset\test_frame\frame_0429.jpg
# Saved D:\Boxing dataset\test_frame\frame_0430.jpg
# Saved D:\Boxing dataset\test_frame\frame_0431.jpg
# Saved D:\Boxing dataset\test_frame\frame_0432.jpg
# Saved D:\Boxing dataset\test_frame\frame_0433.jpg
# Saved D:\Boxing dataset\test_frame\frame_0434.jpg
# Saved D:\Boxing dataset\test_frame\frame_0435.jpg
# Saved D:\Boxing dataset\test_frame\frame_0436.jpg
# Saved D:\Boxing dataset\test_frame\frame_0437.jpg
# Saved D:\Boxing dataset\test_frame\frame_0438.jpg
# Saved D:\Boxing dataset\test_frame\frame_0439.jpg
# Saved D:\Boxing dataset\test_frame\frame_0440.jpg
# Saved D:\Boxing dataset\test_frame\frame_0441.jpg
# Saved D:\Boxing dataset\test_frame\frame_0442.jpg
# Saved D:\Boxing dataset\test_frame\frame_0443.jpg
# Saved D:\Boxing dataset\test_frame\frame_0444.jpg
# Saved D:\Boxing dataset\test_frame\frame_0445.jpg
# Saved D:\Boxing dataset\test_frame\frame_0446.jpg
# Saved D:\Boxing dataset\test_frame\frame_0447.jpg
# Saved D:\Boxing dataset\test_frame\frame_0448.jpg
# Saved D:\Boxing dataset\test_frame\frame_0449.jpg
# Saved D:\Boxing dataset\test_frame\frame_0450.jpg
# Saved D:\Boxing dataset\test_frame\frame_0451.jpg
# Saved D:\Boxing dataset\test_frame\frame_0452.jpg
# Saved D:\Boxing dataset\test_frame\frame_0453.jpg
# Saved D:\Boxing dataset\test_frame\frame_0454.jpg
# Saved D:\Boxing dataset\test_frame\frame_0455.jpg
# Saved D:\Boxing dataset\test_frame\frame_0456.jpg
# Saved D:\Boxing dataset\test_frame\frame_0457.jpg
# Saved D:\Boxing dataset\test_frame\frame_0458.jpg
# Saved D:\Boxing dataset\test_frame\frame_0459.jpg
# Saved D:\Boxing dataset\test_frame\frame_0460.jpg
# Saved D:\Boxing dataset\test_frame\frame_0461.jpg
# Saved D:\Boxing dataset\test_frame\frame_0462.jpg
# Saved D:\Boxing dataset\test_frame\frame_0463.jpg
# Saved D:\Boxing dataset\test_frame\frame_0464.jpg
# Saved D:\Boxing dataset\test_frame\frame_0465.jpg
# Saved D:\Boxing dataset\test_frame\frame_0466.jpg
# Saved D:\Boxing dataset\test_frame\frame_0467.jpg
# Saved D:\Boxing dataset\test_frame\frame_0468.jpg
# Saved D:\Boxing dataset\test_frame\frame_0469.jpg
# Saved D:\Boxing dataset\test_frame\frame_0470.jpg
# Saved D:\Boxing dataset\test_frame\frame_0471.jpg
# Saved D:\Boxing dataset\test_frame\frame_0472.jpg
# Saved D:\Boxing dataset\test_frame\frame_0473.jpg
# Saved D:\Boxing dataset\test_frame\frame_0474.jpg
# Saved D:\Boxing dataset\test_frame\frame_0475.jpg
# Saved D:\Boxing dataset\test_frame\frame_0476.jpg
# Saved D:\Boxing dataset\test_frame\frame_0477.jpg
# Saved D:\Boxing dataset\test_frame\frame_0478.jpg
# Saved D:\Boxing dataset\test_frame\frame_0479.jpg
# Saved D:\Boxing dataset\test_frame\frame_0480.jpg
# Saved D:\Boxing dataset\test_frame\frame_0481.jpg
# Saved D:\Boxing dataset\test_frame\frame_0482.jpg
# Saved D:\Boxing dataset\test_frame\frame_0483.jpg
# Saved D:\Boxing dataset\test_frame\frame_0484.jpg
# Saved D:\Boxing dataset\test_frame\frame_0485.jpg
# Saved D:\Boxing dataset\test_frame\frame_0486.jpg
# Saved D:\Boxing dataset\test_frame\frame_0487.jpg
# Saved D:\Boxing dataset\test_frame\frame_0488.jpg
# Saved D:\Boxing dataset\test_frame\frame_0489.jpg
# Saved D:\Boxing dataset\test_frame\frame_0490.jpg
# Saved D:\Boxing dataset\test_frame\frame_0491.jpg
# Saved D:\Boxing dataset\test_frame\frame_0492.jpg
# Saved D:\Boxing dataset\test_frame\frame_0493.jpg
# Saved D:\Boxing dataset\test_frame\frame_0494.jpg
# Saved D:\Boxing dataset\test_frame\frame_0495.jpg
# Saved D:\Boxing dataset\test_frame\frame_0496.jpg
# Saved D:\Boxing dataset\test_frame\frame_0497.jpg
# Saved D:\Boxing dataset\test_frame\frame_0498.jpg
# Saved D:\Boxing dataset\test_frame\frame_0499.jpg
# Saved D:\Boxing dataset\test_frame\frame_0500.jpg
# Saved D:\Boxing dataset\test_frame\frame_0501.jpg
# Saved D:\Boxing dataset\test_frame\frame_0502.jpg
# Saved D:\Boxing dataset\test_frame\frame_0503.jpg
# Saved D:\Boxing dataset\test_frame\frame_0504.jpg
# Saved D:\Boxing dataset\test_frame\frame_0505.jpg
# Saved D:\Boxing dataset\test_frame\frame_0506.jpg
# Saved D:\Boxing dataset\test_frame\frame_0507.jpg
# Saved D:\Boxing dataset\test_frame\frame_0508.jpg
# Saved D:\Boxing dataset\test_frame\frame_0509.jpg
# Saved D:\Boxing dataset\test_frame\frame_0510.jpg
# Saved D:\Boxing dataset\test_frame\frame_0511.jpg
# Saved D:\Boxing dataset\test_frame\frame_0512.jpg
# Saved D:\Boxing dataset\test_frame\frame_0513.jpg
# Saved D:\Boxing dataset\test_frame\frame_0514.jpg
# Saved D:\Boxing dataset\test_frame\frame_0515.jpg
# Saved D:\Boxing dataset\test_frame\frame_0516.jpg
# Saved D:\Boxing dataset\test_frame\frame_0517.jpg
# Saved D:\Boxing dataset\test_frame\frame_0518.jpg
# Saved D:\Boxing dataset\test_frame\frame_0519.jpg
# Saved D:\Boxing dataset\test_frame\frame_0520.jpg
# Saved D:\Boxing dataset\test_frame\frame_0521.jpg
# Saved D:\Boxing dataset\test_frame\frame_0522.jpg
# Saved D:\Boxing dataset\test_frame\frame_0523.jpg
# Saved D:\Boxing dataset\test_frame\frame_0524.jpg
# Saved D:\Boxing dataset\test_frame\frame_0525.jpg
# Saved D:\Boxing dataset\test_frame\frame_0526.jpg
# Saved D:\Boxing dataset\test_frame\frame_0527.jpg
# Saved D:\Boxing dataset\test_frame\frame_0528.jpg
# Saved D:\Boxing dataset\test_frame\frame_0529.jpg
# Saved D:\Boxing dataset\test_frame\frame_0530.jpg
# Saved D:\Boxing dataset\test_frame\frame_0531.jpg
# Saved D:\Boxing dataset\test_frame\frame_0532.jpg
# Saved D:\Boxing dataset\test_frame\frame_0533.jpg
# Saved D:\Boxing dataset\test_frame\frame_0534.jpg
# Saved D:\Boxing dataset\test_frame\frame_0535.jpg
# Saved D:\Boxing dataset\test_frame\frame_0536.jpg
# Saved D:\Boxing dataset\test_frame\frame_0537.jpg
# Saved D:\Boxing dataset\test_frame\frame_0538.jpg
# Saved D:\Boxing dataset\test_frame\frame_0539.jpg
# Saved D:\Boxing dataset\test_frame\frame_0540.jpg
# Saved D:\Boxing dataset\test_frame\frame_0541.jpg
# Saved D:\Boxing dataset\test_frame\frame_0542.jpg
# Saved D:\Boxing dataset\test_frame\frame_0543.jpg
# Saved D:\Boxing dataset\test_frame\frame_0544.jpg
# Saved D:\Boxing dataset\test_frame\frame_0545.jpg
# Saved D:\Boxing dataset\test_frame\frame_0546.jpg
# Saved D:\Boxing dataset\test_frame\frame_0547.jpg
# Saved D:\Boxing dataset\test_frame\frame_0548.jpg
# Saved D:\Boxing dataset\test_frame\frame_0549.jpg
# Saved D:\Boxing dataset\test_frame\frame_0550.jpg
# Saved D:\Boxing dataset\test_frame\frame_0551.jpg
# Saved D:\Boxing dataset\test_frame\frame_0552.jpg
# Saved D:\Boxing dataset\test_frame\frame_0553.jpg
# Saved D:\Boxing dataset\test_frame\frame_0554.jpg
# Saved D:\Boxing dataset\test_frame\frame_0555.jpg
# Saved D:\Boxing dataset\test_frame\frame_0556.jpg
# Saved D:\Boxing dataset\test_frame\frame_0557.jpg
# Saved D:\Boxing dataset\test_frame\frame_0558.jpg
# Saved D:\Boxing dataset\test_frame\frame_0559.jpg
# Saved D:\Boxing dataset\test_frame\frame_0560.jpg
# Saved D:\Boxing dataset\test_frame\frame_0561.jpg
# Saved D:\Boxing dataset\test_frame\frame_0562.jpg
# Saved D:\Boxing dataset\test_frame\frame_0563.jpg
# Saved D:\Boxing dataset\test_frame\frame_0564.jpg
# Saved D:\Boxing dataset\test_frame\frame_0565.jpg
# Saved D:\Boxing dataset\test_frame\frame_0566.jpg
# Saved D:\Boxing dataset\test_frame\frame_0567.jpg
# Saved D:\Boxing dataset\test_frame\frame_0568.jpg
# Saved D:\Boxing dataset\test_frame\frame_0569.jpg
# Saved D:\Boxing dataset\test_frame\frame_0570.jpg
# Saved D:\Boxing dataset\test_frame\frame_0571.jpg
# Saved D:\Boxing dataset\test_frame\frame_0572.jpg
# Saved D:\Boxing dataset\test_frame\frame_0573.jpg
# Saved D:\Boxing dataset\test_frame\frame_0574.jpg
# Saved D:\Boxing dataset\test_frame\frame_0575.jpg
# Saved D:\Boxing dataset\test_frame\frame_0576.jpg
# Saved D:\Boxing dataset\test_frame\frame_0577.jpg
# Saved D:\Boxing dataset\test_frame\frame_0578.jpg
# Saved D:\Boxing dataset\test_frame\frame_0579.jpg
# Saved D:\Boxing dataset\test_frame\frame_0580.jpg
# Saved D:\Boxing dataset\test_frame\frame_0581.jpg
# Saved D:\Boxing dataset\test_frame\frame_0582.jpg
# Saved D:\Boxing dataset\test_frame\frame_0583.jpg
# Saved D:\Boxing dataset\test_frame\frame_0584.jpg
# Saved D:\Boxing dataset\test_frame\frame_0585.jpg
# Saved D:\Boxing dataset\test_frame\frame_0586.jpg
# Saved D:\Boxing dataset\test_frame\frame_0587.jpg
# Saved D:\Boxing dataset\test_frame\frame_0588.jpg
# Saved D:\Boxing dataset\test_frame\frame_0589.jpg
# Saved D:\Boxing dataset\test_frame\frame_0590.jpg
# Saved D:\Boxing dataset\test_frame\frame_0591.jpg
# Saved D:\Boxing dataset\test_frame\frame_0592.jpg
# Saved D:\Boxing dataset\test_frame\frame_0593.jpg
# Saved D:\Boxing dataset\test_frame\frame_0594.jpg
# Saved D:\Boxing dataset\test_frame\frame_0595.jpg
# Saved D:\Boxing dataset\test_frame\frame_0596.jpg
# Saved D:\Boxing dataset\test_frame\frame_0597.jpg
# Saved D:\Boxing dataset\test_frame\frame_0598.jpg
# Saved D:\Boxing dataset\test_frame\frame_0599.jpg
# Saved D:\Boxing dataset\test_frame\frame_0600.jpg
# Saved D:\Boxing dataset\test_frame\frame_0601.jpg
# Saved D:\Boxing dataset\test_frame\frame_0602.jpg
# Saved D:\Boxing dataset\test_frame\frame_0603.jpg
# Saved D:\Boxing dataset\test_frame\frame_0604.jpg
# Saved D:\Boxing dataset\test_frame\frame_0605.jpg
# Saved D:\Boxing dataset\test_frame\frame_0606.jpg
# Saved D:\Boxing dataset\test_frame\frame_0607.jpg
# Saved D:\Boxing dataset\test_frame\frame_0608.jpg
# Saved D:\Boxing dataset\test_frame\frame_0609.jpg
# Saved D:\Boxing dataset\test_frame\frame_0610.jpg
# Saved D:\Boxing dataset\test_frame\frame_0611.jpg
# Saved D:\Boxing dataset\test_frame\frame_0612.jpg
# Saved D:\Boxing dataset\test_frame\frame_0613.jpg
# Saved D:\Boxing dataset\test_frame\frame_0614.jpg
# Saved D:\Boxing dataset\test_frame\frame_0615.jpg
# Saved D:\Boxing dataset\test_frame\frame_0616.jpg
# Saved D:\Boxing dataset\test_frame\frame_0617.jpg
# Saved D:\Boxing dataset\test_frame\frame_0618.jpg
# Saved D:\Boxing dataset\test_frame\frame_0619.jpg
# Saved D:\Boxing dataset\test_frame\frame_0620.jpg
# Saved D:\Boxing dataset\test_frame\frame_0621.jpg
# Saved D:\Boxing dataset\test_frame\frame_0622.jpg
# Saved D:\Boxing dataset\test_frame\frame_0623.jpg
# Saved D:\Boxing dataset\test_frame\frame_0624.jpg
# Saved D:\Boxing dataset\test_frame\frame_0625.jpg
# Saved D:\Boxing dataset\test_frame\frame_0626.jpg
# Saved D:\Boxing dataset\test_frame\frame_0627.jpg
# Saved D:\Boxing dataset\test_frame\frame_0628.jpg
# Saved D:\Boxing dataset\test_frame\frame_0629.jpg
# Saved D:\Boxing dataset\test_frame\frame_0630.jpg
# Saved D:\Boxing dataset\test_frame\frame_0631.jpg
# Saved D:\Boxing dataset\test_frame\frame_0632.jpg
# Saved D:\Boxing dataset\test_frame\frame_0633.jpg
# Saved D:\Boxing dataset\test_frame\frame_0634.jpg
# Saved D:\Boxing dataset\test_frame\frame_0635.jpg
# Saved D:\Boxing dataset\test_frame\frame_0636.jpg
# Saved D:\Boxing dataset\test_frame\frame_0637.jpg
# Saved D:\Boxing dataset\test_frame\frame_0638.jpg
# Saved D:\Boxing dataset\test_frame\frame_0639.jpg
# Saved D:\Boxing dataset\test_frame\frame_0640.jpg
# Saved D:\Boxing dataset\test_frame\frame_0641.jpg
# Saved D:\Boxing dataset\test_frame\frame_0642.jpg
# Saved D:\Boxing dataset\test_frame\frame_0643.jpg
# Saved D:\Boxing dataset\test_frame\frame_0644.jpg
# Saved D:\Boxing dataset\test_frame\frame_0645.jpg
# Saved D:\Boxing dataset\test_frame\frame_0646.jpg
# Saved D:\Boxing dataset\test_frame\frame_0647.jpg
# Saved D:\Boxing dataset\test_frame\frame_0648.jpg
# Saved D:\Boxing dataset\test_frame\frame_0649.jpg
# Saved D:\Boxing dataset\test_frame\frame_0650.jpg
# Saved D:\Boxing dataset\test_frame\frame_0651.jpg
# Saved D:\Boxing dataset\test_frame\frame_0652.jpg
# Saved D:\Boxing dataset\test_frame\frame_0653.jpg
# Saved D:\Boxing dataset\test_frame\frame_0654.jpg
# Saved D:\Boxing dataset\test_frame\frame_0655.jpg
# Saved D:\Boxing dataset\test_frame\frame_0656.jpg
# Saved D:\Boxing dataset\test_frame\frame_0657.jpg
# Saved D:\Boxing dataset\test_frame\frame_0658.jpg
# Saved D:\Boxing dataset\test_frame\frame_0659.jpg
# Saved D:\Boxing dataset\test_frame\frame_0660.jpg
# Saved D:\Boxing dataset\test_frame\frame_0661.jpg
# Saved D:\Boxing dataset\test_frame\frame_0662.jpg
# Saved D:\Boxing dataset\test_frame\frame_0663.jpg
# Saved D:\Boxing dataset\test_frame\frame_0664.jpg
# Saved D:\Boxing dataset\test_frame\frame_0665.jpg
# Saved D:\Boxing dataset\test_frame\frame_0666.jpg
# Saved D:\Boxing dataset\test_frame\frame_0667.jpg
# Saved D:\Boxing dataset\test_frame\frame_0668.jpg
# Saved D:\Boxing dataset\test_frame\frame_0669.jpg
# Saved D:\Boxing dataset\test_frame\frame_0670.jpg
# Saved D:\Boxing dataset\test_frame\frame_0671.jpg
# Saved D:\Boxing dataset\test_frame\frame_0672.jpg
# Saved D:\Boxing dataset\test_frame\frame_0673.jpg
# Saved D:\Boxing dataset\test_frame\frame_0674.jpg
# Saved D:\Boxing dataset\test_frame\frame_0675.jpg
# Saved D:\Boxing dataset\test_frame\frame_0676.jpg
# Saved D:\Boxing dataset\test_frame\frame_0677.jpg
# Saved D:\Boxing dataset\test_frame\frame_0678.jpg
# Saved D:\Boxing dataset\test_frame\frame_0679.jpg
# Saved D:\Boxing dataset\test_frame\frame_0680.jpg
# Saved D:\Boxing dataset\test_frame\frame_0681.jpg
# Saved D:\Boxing dataset\test_frame\frame_0682.jpg
# Saved D:\Boxing dataset\test_frame\frame_0683.jpg
# Saved D:\Boxing dataset\test_frame\frame_0684.jpg
# Saved D:\Boxing dataset\test_frame\frame_0685.jpg
# Saved D:\Boxing dataset\test_frame\frame_0686.jpg
# Saved D:\Boxing dataset\test_frame\frame_0687.jpg
# Saved D:\Boxing dataset\test_frame\frame_0688.jpg
# Saved D:\Boxing dataset\test_frame\frame_0689.jpg
# Saved D:\Boxing dataset\test_frame\frame_0690.jpg
# Saved D:\Boxing dataset\test_frame\frame_0691.jpg
# Saved D:\Boxing dataset\test_frame\frame_0692.jpg
# Saved D:\Boxing dataset\test_frame\frame_0693.jpg
# Saved D:\Boxing dataset\test_frame\frame_0694.jpg
# Saved D:\Boxing dataset\test_frame\frame_0695.jpg
# Saved D:\Boxing dataset\test_frame\frame_0696.jpg
# Saved D:\Boxing dataset\test_frame\frame_0697.jpg
# Saved D:\Boxing dataset\test_frame\frame_0698.jpg
# Saved D:\Boxing dataset\test_frame\frame_0699.jpg
# Saved D:\Boxing dataset\test_frame\frame_0700.jpg
# Saved D:\Boxing dataset\test_frame\frame_0701.jpg
# Saved D:\Boxing dataset\test_frame\frame_0702.jpg
# Saved D:\Boxing dataset\test_frame\frame_0703.jpg
# Saved D:\Boxing dataset\test_frame\frame_0704.jpg
# Saved D:\Boxing dataset\test_frame\frame_0705.jpg
# Saved D:\Boxing dataset\test_frame\frame_0706.jpg
# Saved D:\Boxing dataset\test_frame\frame_0707.jpg
# Saved D:\Boxing dataset\test_frame\frame_0708.jpg
# Saved D:\Boxing dataset\test_frame\frame_0709.jpg
# Saved D:\Boxing dataset\test_frame\frame_0710.jpg
# Saved D:\Boxing dataset\test_frame\frame_0711.jpg
# Saved D:\Boxing dataset\test_frame\frame_0712.jpg
# Saved D:\Boxing dataset\test_frame\frame_0713.jpg
# Saved D:\Boxing dataset\test_frame\frame_0714.jpg
# Saved D:\Boxing dataset\test_frame\frame_0715.jpg
# Saved D:\Boxing dataset\test_frame\frame_0716.jpg
# Saved D:\Boxing dataset\test_frame\frame_0717.jpg
# Saved D:\Boxing dataset\test_frame\frame_0718.jpg
# Saved D:\Boxing dataset\test_frame\frame_0719.jpg
# Saved D:\Boxing dataset\test_frame\frame_0720.jpg
# Saved D:\Boxing dataset\test_frame\frame_0721.jpg
# Saved D:\Boxing dataset\test_frame\frame_0722.jpg
# Saved D:\Boxing dataset\test_frame\frame_0723.jpg
# Saved D:\Boxing dataset\test_frame\frame_0724.jpg
# Saved D:\Boxing dataset\test_frame\frame_0725.jpg
# Saved D:\Boxing dataset\test_frame\frame_0726.jpg
# Saved D:\Boxing dataset\test_frame\frame_0727.jpg
# Saved D:\Boxing dataset\test_frame\frame_0728.jpg
# Saved D:\Boxing dataset\test_frame\frame_0729.jpg
# Saved D:\Boxing dataset\test_frame\frame_0730.jpg
# Saved D:\Boxing dataset\test_frame\frame_0731.jpg
# Saved D:\Boxing dataset\test_frame\frame_0732.jpg
# Saved D:\Boxing dataset\test_frame\frame_0733.jpg
# Saved D:\Boxing dataset\test_frame\frame_0734.jpg
# Saved D:\Boxing dataset\test_frame\frame_0735.jpg
# Saved D:\Boxing dataset\test_frame\frame_0736.jpg
# Saved D:\Boxing dataset\test_frame\frame_0737.jpg
# Saved D:\Boxing dataset\test_frame\frame_0738.jpg
# Saved D:\Boxing dataset\test_frame\frame_0739.jpg
# Saved D:\Boxing dataset\test_frame\frame_0740.jpg
# Saved D:\Boxing dataset\test_frame\frame_0741.jpg
# Saved D:\Boxing dataset\test_frame\frame_0742.jpg
# Saved D:\Boxing dataset\test_frame\frame_0743.jpg
# Saved D:\Boxing dataset\test_frame\frame_0744.jpg
# Saved D:\Boxing dataset\test_frame\frame_0745.jpg
# Saved D:\Boxing dataset\test_frame\frame_0746.jpg
# Saved D:\Boxing dataset\test_frame\frame_0747.jpg
# Saved D:\Boxing dataset\test_frame\frame_0748.jpg
# Saved D:\Boxing dataset\test_frame\frame_0749.jpg
# Saved D:\Boxing dataset\test_frame\frame_0750.jpg
# Saved D:\Boxing dataset\test_frame\frame_0751.jpg
# Saved D:\Boxing dataset\test_frame\frame_0752.jpg
# Saved D:\Boxing dataset\test_frame\frame_0753.jpg
# Saved D:\Boxing dataset\test_frame\frame_0754.jpg
# Saved D:\Boxing dataset\test_frame\frame_0755.jpg
# Saved D:\Boxing dataset\test_frame\frame_0756.jpg
# Saved D:\Boxing dataset\test_frame\frame_0757.jpg
# Saved D:\Boxing dataset\test_frame\frame_0758.jpg
# Saved D:\Boxing dataset\test_frame\frame_0759.jpg
# Saved D:\Boxing dataset\test_frame\frame_0760.jpg
# Saved D:\Boxing dataset\test_frame\frame_0761.jpg
# Saved D:\Boxing dataset\test_frame\frame_0762.jpg
# Saved D:\Boxing dataset\test_frame\frame_0763.jpg
# Saved D:\Boxing dataset\test_frame\frame_0764.jpg
# Saved D:\Boxing dataset\test_frame\frame_0765.jpg
# Saved D:\Boxing dataset\test_frame\frame_0766.jpg
# Saved D:\Boxing dataset\test_frame\frame_0767.jpg
# Saved D:\Boxing dataset\test_frame\frame_0768.jpg
# Saved D:\Boxing dataset\test_frame\frame_0769.jpg
# Saved D:\Boxing dataset\test_frame\frame_0770.jpg
# Saved D:\Boxing dataset\test_frame\frame_0771.jpg
# Saved D:\Boxing dataset\test_frame\frame_0772.jpg
# Saved D:\Boxing dataset\test_frame\frame_0773.jpg
# Saved D:\Boxing dataset\test_frame\frame_0774.jpg
# Saved D:\Boxing dataset\test_frame\frame_0775.jpg
# Saved D:\Boxing dataset\test_frame\frame_0776.jpg
# Saved D:\Boxing dataset\test_frame\frame_0777.jpg
# Saved D:\Boxing dataset\test_frame\frame_0778.jpg
# Saved D:\Boxing dataset\test_frame\frame_0779.jpg
# Saved D:\Boxing dataset\test_frame\frame_0780.jpg
# Saved D:\Boxing dataset\test_frame\frame_0781.jpg
# Saved D:\Boxing dataset\test_frame\frame_0782.jpg
# Saved D:\Boxing dataset\test_frame\frame_0783.jpg
# Saved D:\Boxing dataset\test_frame\frame_0784.jpg
# Saved D:\Boxing dataset\test_frame\frame_0785.jpg
# Saved D:\Boxing dataset\test_frame\frame_0786.jpg
# Saved D:\Boxing dataset\test_frame\frame_0787.jpg
# Saved D:\Boxing dataset\test_frame\frame_0788.jpg
# Saved D:\Boxing dataset\test_frame\frame_0789.jpg
# Saved D:\Boxing dataset\test_frame\frame_0790.jpg
# Saved D:\Boxing dataset\test_frame\frame_0791.jpg
# Saved D:\Boxing dataset\test_frame\frame_0792.jpg
# Saved D:\Boxing dataset\test_frame\frame_0793.jpg
# Saved D:\Boxing dataset\test_frame\frame_0794.jpg
# Saved D:\Boxing dataset\test_frame\frame_0795.jpg
# Saved D:\Boxing dataset\test_frame\frame_0796.jpg
# Saved D:\Boxing dataset\test_frame\frame_0797.jpg
# Saved D:\Boxing dataset\test_frame\frame_0798.jpg
# Saved D:\Boxing dataset\test_frame\frame_0799.jpg
# Saved D:\Boxing dataset\test_frame\frame_0800.jpg
# Saved D:\Boxing dataset\test_frame\frame_0801.jpg
# Saved D:\Boxing dataset\test_frame\frame_0802.jpg
# Saved D:\Boxing dataset\test_frame\frame_0803.jpg
# Saved D:\Boxing dataset\test_frame\frame_0804.jpg
# Saved D:\Boxing dataset\test_frame\frame_0805.jpg
# Saved D:\Boxing dataset\test_frame\frame_0806.jpg
# Saved D:\Boxing dataset\test_frame\frame_0807.jpg
# Saved D:\Boxing dataset\test_frame\frame_0808.jpg
# Saved D:\Boxing dataset\test_frame\frame_0809.jpg
# Saved D:\Boxing dataset\test_frame\frame_0810.jpg
# Saved D:\Boxing dataset\test_frame\frame_0811.jpg
# Saved D:\Boxing dataset\test_frame\frame_0812.jpg
# Saved D:\Boxing dataset\test_frame\frame_0813.jpg
# Saved D:\Boxing dataset\test_frame\frame_0814.jpg
# Saved D:\Boxing dataset\test_frame\frame_0815.jpg
# Saved D:\Boxing dataset\test_frame\frame_0816.jpg
# Saved D:\Boxing dataset\test_frame\frame_0817.jpg
# Saved D:\Boxing dataset\test_frame\frame_0818.jpg
# Saved D:\Boxing dataset\test_frame\frame_0819.jpg
# Saved D:\Boxing dataset\test_frame\frame_0820.jpg
# Saved D:\Boxing dataset\test_frame\frame_0821.jpg
# Saved D:\Boxing dataset\test_frame\frame_0822.jpg
# Saved D:\Boxing dataset\test_frame\frame_0823.jpg
# Saved D:\Boxing dataset\test_frame\frame_0824.jpg
# Saved D:\Boxing dataset\test_frame\frame_0825.jpg
# Saved D:\Boxing dataset\test_frame\frame_0826.jpg
# Saved D:\Boxing dataset\test_frame\frame_0827.jpg
# Saved D:\Boxing dataset\test_frame\frame_0828.jpg
# Saved D:\Boxing dataset\test_frame\frame_0829.jpg
# Saved D:\Boxing dataset\test_frame\frame_0830.jpg
# Saved D:\Boxing dataset\test_frame\frame_0831.jpg
# Saved D:\Boxing dataset\test_frame\frame_0832.jpg
# Saved D:\Boxing dataset\test_frame\frame_0833.jpg
# Saved D:\Boxing dataset\test_frame\frame_0834.jpg
# Saved D:\Boxing dataset\test_frame\frame_0835.jpg
# Saved D:\Boxing dataset\test_frame\frame_0836.jpg
# Saved D:\Boxing dataset\test_frame\frame_0837.jpg
# Saved D:\Boxing dataset\test_frame\frame_0838.jpg
# Saved D:\Boxing dataset\test_frame\frame_0839.jpg
# Saved D:\Boxing dataset\test_frame\frame_0840.jpg
# Saved D:\Boxing dataset\test_frame\frame_0841.jpg
# Saved D:\Boxing dataset\test_frame\frame_0842.jpg
# Saved D:\Boxing dataset\test_frame\frame_0843.jpg
# Saved D:\Boxing dataset\test_frame\frame_0844.jpg
# Saved D:\Boxing dataset\test_frame\frame_0845.jpg
# Saved D:\Boxing dataset\test_frame\frame_0846.jpg
# Saved D:\Boxing dataset\test_frame\frame_0847.jpg
# Saved D:\Boxing dataset\test_frame\frame_0848.jpg
# Saved D:\Boxing dataset\test_frame\frame_0849.jpg
# Saved D:\Boxing dataset\test_frame\frame_0850.jpg
# Saved D:\Boxing dataset\test_frame\frame_0851.jpg
# Saved D:\Boxing dataset\test_frame\frame_0852.jpg
# Saved D:\Boxing dataset\test_frame\frame_0853.jpg
# Saved D:\Boxing dataset\test_frame\frame_0854.jpg
# Saved D:\Boxing dataset\test_frame\frame_0855.jpg
# Saved D:\Boxing dataset\test_frame\frame_0856.jpg
# Saved D:\Boxing dataset\test_frame\frame_0857.jpg
# Saved D:\Boxing dataset\test_frame\frame_0858.jpg
# Saved D:\Boxing dataset\test_frame\frame_0859.jpg
# Saved D:\Boxing dataset\test_frame\frame_0860.jpg
# Saved D:\Boxing dataset\test_frame\frame_0861.jpg
# Saved D:\Boxing dataset\test_frame\frame_0862.jpg
# Saved D:\Boxing dataset\test_frame\frame_0863.jpg
# Saved D:\Boxing dataset\test_frame\frame_0864.jpg
# Saved D:\Boxing dataset\test_frame\frame_0865.jpg
# Saved D:\Boxing dataset\test_frame\frame_0866.jpg
# Saved D:\Boxing dataset\test_frame\frame_0867.jpg
# Saved D:\Boxing dataset\test_frame\frame_0868.jpg
# Saved D:\Boxing dataset\test_frame\frame_0869.jpg
# Saved D:\Boxing dataset\test_frame\frame_0870.jpg
# Saved D:\Boxing dataset\test_frame\frame_0871.jpg
# Saved D:\Boxing dataset\test_frame\frame_0872.jpg
# Saved D:\Boxing dataset\test_frame\frame_0873.jpg
# Saved D:\Boxing dataset\test_frame\frame_0874.jpg
# Saved D:\Boxing dataset\test_frame\frame_0875.jpg
# Saved D:\Boxing dataset\test_frame\frame_0876.jpg
# Saved D:\Boxing dataset\test_frame\frame_0877.jpg
# Saved D:\Boxing dataset\test_frame\frame_0878.jpg
# Saved D:\Boxing dataset\test_frame\frame_0879.jpg
# Saved D:\Boxing dataset\test_frame\frame_0880.jpg
# Saved D:\Boxing dataset\test_frame\frame_0881.jpg
# Saved D:\Boxing dataset\test_frame\frame_0882.jpg
# Saved D:\Boxing dataset\test_frame\frame_0883.jpg
# Saved D:\Boxing dataset\test_frame\frame_0884.jpg
# Saved D:\Boxing dataset\test_frame\frame_0885.jpg
# Saved D:\Boxing dataset\test_frame\frame_0886.jpg
# Saved D:\Boxing dataset\test_frame\frame_0887.jpg
# Saved D:\Boxing dataset\test_frame\frame_0888.jpg
# Saved D:\Boxing dataset\test_frame\frame_0889.jpg
# Saved D:\Boxing dataset\test_frame\frame_0890.jpg
# Saved D:\Boxing dataset\test_frame\frame_0891.jpg
# Saved D:\Boxing dataset\test_frame\frame_0892.jpg
# Saved D:\Boxing dataset\test_frame\frame_0893.jpg
# Saved D:\Boxing dataset\test_frame\frame_0894.jpg
# Saved D:\Boxing dataset\test_frame\frame_0895.jpg
# Saved D:\Boxing dataset\test_frame\frame_0896.jpg
# Saved D:\Boxing dataset\test_frame\frame_0897.jpg
# Saved D:\Boxing dataset\test_frame\frame_0898.jpg
# Saved D:\Boxing dataset\test_frame\frame_0899.jpg
# Saved D:\Boxing dataset\test_frame\frame_0900.jpg
# Saved D:\Boxing dataset\test_frame\frame_0901.jpg
# Saved D:\Boxing dataset\test_frame\frame_0902.jpg
# Saved D:\Boxing dataset\test_frame\frame_0903.jpg
# Saved D:\Boxing dataset\test_frame\frame_0904.jpg
# Saved D:\Boxing dataset\test_frame\frame_0905.jpg
# Saved D:\Boxing dataset\test_frame\frame_0906.jpg
# Saved D:\Boxing dataset\test_frame\frame_0907.jpg
# Saved D:\Boxing dataset\test_frame\frame_0908.jpg
# Saved D:\Boxing dataset\test_frame\frame_0909.jpg
# Saved D:\Boxing dataset\test_frame\frame_0910.jpg
# Saved D:\Boxing dataset\test_frame\frame_0911.jpg
# Saved D:\Boxing dataset\test_frame\frame_0912.jpg
# Saved D:\Boxing dataset\test_frame\frame_0913.jpg
# Saved D:\Boxing dataset\test_frame\frame_0914.jpg
# Saved D:\Boxing dataset\test_frame\frame_0915.jpg
# Saved D:\Boxing dataset\test_frame\frame_0916.jpg
# Saved D:\Boxing dataset\test_frame\frame_0917.jpg
# Saved D:\Boxing dataset\test_frame\frame_0918.jpg
# Saved D:\Boxing dataset\test_frame\frame_0919.jpg
# Saved D:\Boxing dataset\test_frame\frame_0920.jpg
# Saved D:\Boxing dataset\test_frame\frame_0921.jpg
# Saved D:\Boxing dataset\test_frame\frame_0922.jpg
# Saved D:\Boxing dataset\test_frame\frame_0923.jpg
# Saved D:\Boxing dataset\test_frame\frame_0924.jpg
# Saved D:\Boxing dataset\test_frame\frame_0925.jpg
# Saved D:\Boxing dataset\test_frame\frame_0926.jpg
# Saved D:\Boxing dataset\test_frame\frame_0927.jpg
# Saved D:\Boxing dataset\test_frame\frame_0928.jpg
# Saved D:\Boxing dataset\test_frame\frame_0929.jpg
# Saved D:\Boxing dataset\test_frame\frame_0930.jpg
# Saved D:\Boxing dataset\test_frame\frame_0931.jpg
# Saved D:\Boxing dataset\test_frame\frame_0932.jpg
# Saved D:\Boxing dataset\test_frame\frame_0933.jpg
# Saved D:\Boxing dataset\test_frame\frame_0934.jpg
# Saved D:\Boxing dataset\test_frame\frame_0935.jpg
# Saved D:\Boxing dataset\test_frame\frame_0936.jpg
# Saved D:\Boxing dataset\test_frame\frame_0937.jpg
# Saved D:\Boxing dataset\test_frame\frame_0938.jpg
# Saved D:\Boxing dataset\test_frame\frame_0939.jpg
# Saved D:\Boxing dataset\test_frame\frame_0940.jpg
# Saved D:\Boxing dataset\test_frame\frame_0941.jpg
# Saved D:\Boxing dataset\test_frame\frame_0942.jpg
# Saved D:\Boxing dataset\test_frame\frame_0943.jpg
# Saved D:\Boxing dataset\test_frame\frame_0944.jpg
# Saved D:\Boxing dataset\test_frame\frame_0945.jpg
# Saved D:\Boxing dataset\test_frame\frame_0946.jpg
# Saved D:\Boxing dataset\test_frame\frame_0947.jpg
# Saved D:\Boxing dataset\test_frame\frame_0948.jpg
# Saved D:\Boxing dataset\test_frame\frame_0949.jpg
# Saved D:\Boxing dataset\test_frame\frame_0950.jpg
# Saved D:\Boxing dataset\test_frame\frame_0951.jpg
# Saved D:\Boxing dataset\test_frame\frame_0952.jpg
# Saved D:\Boxing dataset\test_frame\frame_0953.jpg
# Saved D:\Boxing dataset\test_frame\frame_0954.jpg
# Saved D:\Boxing dataset\test_frame\frame_0955.jpg
# Saved D:\Boxing dataset\test_frame\frame_0956.jpg
# Saved D:\Boxing dataset\test_frame\frame_0957.jpg
# Saved D:\Boxing dataset\test_frame\frame_0958.jpg
# Saved D:\Boxing dataset\test_frame\frame_0959.jpg
# ...
# Saved D:\Boxing dataset\test_frame\frame_7531.jpg
# Saved D:\Boxing dataset\test_frame\frame_7532.jpg
# Saved D:\Boxing dataset\test_frame\frame_7533.jpg
# Saved D:\Boxing dataset\test_frame\frame_7534.jpg
# Saved D:\Boxing dataset\test_frame\frame_7535.jpg
# Saved D:\Boxing dataset\test_frame\frame_7536.jpg
# Saved D:\Boxing dataset\test_frame\frame_7537.jpg
# Saved D:\Boxing dataset\test_frame\frame_7538.jpg
# Saved D:\Boxing dataset\test_frame\frame_7539.jpg
# Saved D:\Boxing dataset\test_frame\frame_7540.jpg
# Saved D:\Boxing dataset\test_frame\frame_7541.jpg
# Saved D:\Boxing dataset\test_frame\frame_7542.jpg
# Saved D:\Boxing dataset\test_frame\frame_7543.jpg
# Saved D:\Boxing dataset\test_frame\frame_7544.jpg
# Saved D:\Boxing dataset\test_frame\frame_7545.jpg
# Saved D:\Boxing dataset\test_frame\frame_7546.jpg
# Saved D:\Boxing dataset\test_frame\frame_7547.jpg
# Saved D:\Boxing dataset\test_frame\frame_7548.jpg
# Saved D:\Boxing dataset\test_frame\frame_7549.jpg
# Saved D:\Boxing dataset\test_frame\frame_7550.jpg
# Saved D:\Boxing dataset\test_frame\frame_7551.jpg
# Saved D:\Boxing dataset\test_frame\frame_7552.jpg
# Saved D:\Boxing dataset\test_frame\frame_7553.jpg
# Saved D:\Boxing dataset\test_frame\frame_7554.jpg
# Saved D:\Boxing dataset\test_frame\frame_7555.jpg
# Saved D:\Boxing dataset\test_frame\frame_7556.jpg
# Saved D:\Boxing dataset\test_frame\frame_7557.jpg
# Saved D:\Boxing dataset\test_frame\frame_7558.jpg
# Saved D:\Boxing dataset\test_frame\frame_7559.jpg
# Saved D:\Boxing dataset\test_frame\frame_7560.jpg
# Saved D:\Boxing dataset\test_frame\frame_7561.jpg
# Saved D:\Boxing dataset\test_frame\frame_7562.jpg
# Saved D:\Boxing dataset\test_frame\frame_7563.jpg
# Saved D:\Boxing dataset\test_frame\frame_7564.jpg
# Saved D:\Boxing dataset\test_frame\frame_7565.jpg
# Saved D:\Boxing dataset\test_frame\frame_7566.jpg
# Saved D:\Boxing dataset\test_frame\frame_7567.jpg
# Saved D:\Boxing dataset\test_frame\frame_7568.jpg
# Saved D:\Boxing dataset\test_frame\frame_7569.jpg
# Saved D:\Boxing dataset\test_frame\frame_7570.jpg
# Saved D:\Boxing dataset\test_frame\frame_7571.jpg
# Saved D:\Boxing dataset\test_frame\frame_7572.jpg
# Saved D:\Boxing dataset\test_frame\frame_7573.jpg
# Saved D:\Boxing dataset\test_frame\frame_7574.jpg
# Saved D:\Boxing dataset\test_frame\frame_7575.jpg
# Saved D:\Boxing dataset\test_frame\frame_7576.jpg
# Saved D:\Boxing dataset\test_frame\frame_7577.jpg
# Saved D:\Boxing dataset\test_frame\frame_7578.jpg
# Saved D:\Boxing dataset\test_frame\frame_7579.jpg
# Saved D:\Boxing dataset\test_frame\frame_7580.jpg
# Saved D:\Boxing dataset\test_frame\frame_7581.jpg
# Saved D:\Boxing dataset\test_frame\frame_7582.jpg
# Saved D:\Boxing dataset\test_frame\frame_7583.jpg
# Saved D:\Boxing dataset\test_frame\frame_7584.jpg
# Saved D:\Boxing dataset\test_frame\frame_7585.jpg
# Saved D:\Boxing dataset\test_frame\frame_7586.jpg
# Saved D:\Boxing dataset\test_frame\frame_7587.jpg
# Saved D:\Boxing dataset\test_frame\frame_7588.jpg
# Saved D:\Boxing dataset\test_frame\frame_7589.jpg
# Saved D:\Boxing dataset\test_frame\frame_7590.jpg
# Saved D:\Boxing dataset\test_frame\frame_7591.jpg
# Saved D:\Boxing dataset\test_frame\frame_7592.jpg
# Saved D:\Boxing dataset\test_frame\frame_7593.jpg
# Saved D:\Boxing dataset\test_frame\frame_7594.jpg
# Saved D:\Boxing dataset\test_frame\frame_7595.jpg
# Saved D:\Boxing dataset\test_frame\frame_7596.jpg
# Saved D:\Boxing dataset\test_frame\frame_7597.jpg
# Saved D:\Boxing dataset\test_frame\frame_7598.jpg
# Saved D:\Boxing dataset\test_frame\frame_7599.jpg
# Saved D:\Boxing dataset\test_frame\frame_7600.jpg
# Saved D:\Boxing dataset\test_frame\frame_7601.jpg
# Saved D:\Boxing dataset\test_frame\frame_7602.jpg
# Saved D:\Boxing dataset\test_frame\frame_7603.jpg
# Saved D:\Boxing dataset\test_frame\frame_7604.jpg
# Saved D:\Boxing dataset\test_frame\frame_7605.jpg
# Saved D:\Boxing dataset\test_frame\frame_7606.jpg
# Saved D:\Boxing dataset\test_frame\frame_7607.jpg
# Saved D:\Boxing dataset\test_frame\frame_7608.jpg
# Saved D:\Boxing dataset\test_frame\frame_7609.jpg
# Saved D:\Boxing dataset\test_frame\frame_7610.jpg
# Saved D:\Boxing dataset\test_frame\frame_7611.jpg
# Saved D:\Boxing dataset\test_frame\frame_7612.jpg
# Saved D:\Boxing dataset\test_frame\frame_7613.jpg
# Saved D:\Boxing dataset\test_frame\frame_7614.jpg
# Saved D:\Boxing dataset\test_frame\frame_7615.jpg
# Saved D:\Boxing dataset\test_frame\frame_7616.jpg
# Saved D:\Boxing dataset\test_frame\frame_7617.jpg
# Saved D:\Boxing dataset\test_frame\frame_7618.jpg
# Saved D:\Boxing dataset\test_frame\frame_7619.jpg
# Saved D:\Boxing dataset\test_frame\frame_7620.jpg
# Saved D:\Boxing dataset\test_frame\frame_7621.jpg
# Saved D:\Boxing dataset\test_frame\frame_7622.jpg
# Saved D:\Boxing dataset\test_frame\frame_7623.jpg
# Saved D:\Boxing dataset\test_frame\frame_7624.jpg
# Saved D:\Boxing dataset\test_frame\frame_7625.jpg
# Saved D:\Boxing dataset\test_frame\frame_7626.jpg
# Saved D:\Boxing dataset\test_frame\frame_7627.jpg
# Saved D:\Boxing dataset\test_frame\frame_7628.jpg
# Saved D:\Boxing dataset\test_frame\frame_7629.jpg
# Saved D:\Boxing dataset\test_frame\frame_7630.jpg
# Saved D:\Boxing dataset\test_frame\frame_7631.jpg
# Saved D:\Boxing dataset\test_frame\frame_7632.jpg
# Saved D:\Boxing dataset\test_frame\frame_7633.jpg
# Saved D:\Boxing dataset\test_frame\frame_7634.jpg
# Saved D:\Boxing dataset\test_frame\frame_7635.jpg
# Saved D:\Boxing dataset\test_frame\frame_7636.jpg
# Saved D:\Boxing dataset\test_frame\frame_7637.jpg
# Saved D:\Boxing dataset\test_frame\frame_7638.jpg
# Saved D:\Boxing dataset\test_frame\frame_7639.jpg
# Saved D:\Boxing dataset\test_frame\frame_7640.jpg
# Saved D:\Boxing dataset\test_frame\frame_7641.jpg
# Saved D:\Boxing dataset\test_frame\frame_7642.jpg
# Saved D:\Boxing dataset\test_frame\frame_7643.jpg
# Saved D:\Boxing dataset\test_frame\frame_7644.jpg
# Saved D:\Boxing dataset\test_frame\frame_7645.jpg
# Saved D:\Boxing dataset\test_frame\frame_7646.jpg
# Saved D:\Boxing dataset\test_frame\frame_7647.jpg
# Saved D:\Boxing dataset\test_frame\frame_7648.jpg
# Saved D:\Boxing dataset\test_frame\frame_7649.jpg
# Saved D:\Boxing dataset\test_frame\frame_7650.jpg
# Saved D:\Boxing dataset\test_frame\frame_7651.jpg
# Saved D:\Boxing dataset\test_frame\frame_7652.jpg
# Saved D:\Boxing dataset\test_frame\frame_7653.jpg
# Saved D:\Boxing dataset\test_frame\frame_7654.jpg
# Saved D:\Boxing dataset\test_frame\frame_7655.jpg
# Saved D:\Boxing dataset\test_frame\frame_7656.jpg
# Saved D:\Boxing dataset\test_frame\frame_7657.jpg
# Saved D:\Boxing dataset\test_frame\frame_7658.jpg
# Saved D:\Boxing dataset\test_frame\frame_7659.jpg
# Saved D:\Boxing dataset\test_frame\frame_7660.jpg
# Saved D:\Boxing dataset\test_frame\frame_7661.jpg
# Saved D:\Boxing dataset\test_frame\frame_7662.jpg
# Saved D:\Boxing dataset\test_frame\frame_7663.jpg
# Saved D:\Boxing dataset\test_frame\frame_7664.jpg
# Saved D:\Boxing dataset\test_frame\frame_7665.jpg
# Saved D:\Boxing dataset\test_frame\frame_7666.jpg
# Saved D:\Boxing dataset\test_frame\frame_7667.jpg
# Saved D:\Boxing dataset\test_frame\frame_7668.jpg
# Saved D:\Boxing dataset\test_frame\frame_7669.jpg
# Saved D:\Boxing dataset\test_frame\frame_7670.jpg
# Saved D:\Boxing dataset\test_frame\frame_7671.jpg
# Saved D:\Boxing dataset\test_frame\frame_7672.jpg
# Saved D:\Boxing dataset\test_frame\frame_7673.jpg
# Saved D:\Boxing dataset\test_frame\frame_7674.jpg
# Saved D:\Boxing dataset\test_frame\frame_7675.jpg
# Saved D:\Boxing dataset\test_frame\frame_7676.jpg
# Saved D:\Boxing dataset\test_frame\frame_7677.jpg
# Saved D:\Boxing dataset\test_frame\frame_7678.jpg
# Saved D:\Boxing dataset\test_frame\frame_7679.jpg
# Saved D:\Boxing dataset\test_frame\frame_7680.jpg
# Saved D:\Boxing dataset\test_frame\frame_7681.jpg
# Saved D:\Boxing dataset\test_frame\frame_7682.jpg
# Saved D:\Boxing dataset\test_frame\frame_7683.jpg
# Saved D:\Boxing dataset\test_frame\frame_7684.jpg
# Saved D:\Boxing dataset\test_frame\frame_7685.jpg
# Saved D:\Boxing dataset\test_frame\frame_7686.jpg
# Saved D:\Boxing dataset\test_frame\frame_7687.jpg
# Saved D:\Boxing dataset\test_frame\frame_7688.jpg
# Saved D:\Boxing dataset\test_frame\frame_7689.jpg
# Saved D:\Boxing dataset\test_frame\frame_7690.jpg
# Saved D:\Boxing dataset\test_frame\frame_7691.jpg
# Saved D:\Boxing dataset\test_frame\frame_7692.jpg
# Saved D:\Boxing dataset\test_frame\frame_7693.jpg
# Saved D:\Boxing dataset\test_frame\frame_7694.jpg
# Saved D:\Boxing dataset\test_frame\frame_7695.jpg
# Saved D:\Boxing dataset\test_frame\frame_7696.jpg
# Saved D:\Boxing dataset\test_frame\frame_7697.jpg
# Saved D:\Boxing dataset\test_frame\frame_7698.jpg
# Saved D:\Boxing dataset\test_frame\frame_7699.jpg
# Saved D:\Boxing dataset\test_frame\frame_7700.jpg
# Saved D:\Boxing dataset\test_frame\frame_7701.jpg
# Saved D:\Boxing dataset\test_frame\frame_7702.jpg
# Saved D:\Boxing dataset\test_frame\frame_7703.jpg
# Saved D:\Boxing dataset\test_frame\frame_7704.jpg
# Saved D:\Boxing dataset\test_frame\frame_7705.jpg
# Saved D:\Boxing dataset\test_frame\frame_7706.jpg
# Saved D:\Boxing dataset\test_frame\frame_7707.jpg
# Saved D:\Boxing dataset\test_frame\frame_7708.jpg
# Saved D:\Boxing dataset\test_frame\frame_7709.jpg
# Saved D:\Boxing dataset\test_frame\frame_7710.jpg
# Saved D:\Boxing dataset\test_frame\frame_7711.jpg
# Saved D:\Boxing dataset\test_frame\frame_7712.jpg
# Saved D:\Boxing dataset\test_frame\frame_7713.jpg
# Saved D:\Boxing dataset\test_frame\frame_7714.jpg
# Saved D:\Boxing dataset\test_frame\frame_7715.jpg
# Saved D:\Boxing dataset\test_frame\frame_7716.jpg
# Saved D:\Boxing dataset\test_frame\frame_7717.jpg
# Saved D:\Boxing dataset\test_frame\frame_7718.jpg
# Saved D:\Boxing dataset\test_frame\frame_7719.jpg
# Saved D:\Boxing dataset\test_frame\frame_7720.jpg
# Saved D:\Boxing dataset\test_frame\frame_7721.jpg
# Saved D:\Boxing dataset\test_frame\frame_7722.jpg
# Saved D:\Boxing dataset\test_frame\frame_7723.jpg
# Saved D:\Boxing dataset\test_frame\frame_7724.jpg
# Saved D:\Boxing dataset\test_frame\frame_7725.jpg
# Saved D:\Boxing dataset\test_frame\frame_7726.jpg
# Saved D:\Boxing dataset\test_frame\frame_7727.jpg
# Saved D:\Boxing dataset\test_frame\frame_7728.jpg
# Saved D:\Boxing dataset\test_frame\frame_7729.jpg
# Saved D:\Boxing dataset\test_frame\frame_7730.jpg
# Saved D:\Boxing dataset\test_frame\frame_7731.jpg
# Saved D:\Boxing dataset\test_frame\frame_7732.jpg
# Saved D:\Boxing dataset\test_frame\frame_7733.jpg
# Saved D:\Boxing dataset\test_frame\frame_7734.jpg
# Saved D:\Boxing dataset\test_frame\frame_7735.jpg
# Saved D:\Boxing dataset\test_frame\frame_7736.jpg
# Saved D:\Boxing dataset\test_frame\frame_7737.jpg
# Saved D:\Boxing dataset\test_frame\frame_7738.jpg
# Saved D:\Boxing dataset\test_frame\frame_7739.jpg
# Saved D:\Boxing dataset\test_frame\frame_7740.jpg
# Saved D:\Boxing dataset\test_frame\frame_7741.jpg
# Saved D:\Boxing dataset\test_frame\frame_7742.jpg
# Saved D:\Boxing dataset\test_frame\frame_7743.jpg
# Saved D:\Boxing dataset\test_frame\frame_7744.jpg
# Saved D:\Boxing dataset\test_frame\frame_7745.jpg
# Saved D:\Boxing dataset\test_frame\frame_7746.jpg
# Saved D:\Boxing dataset\test_frame\frame_7747.jpg
# Saved D:\Boxing dataset\test_frame\frame_7748.jpg
# Saved D:\Boxing dataset\test_frame\frame_7749.jpg
# Saved D:\Boxing dataset\test_frame\frame_7750.jpg
# Saved D:\Boxing dataset\test_frame\frame_7751.jpg
# Saved D:\Boxing dataset\test_frame\frame_7752.jpg
# Saved D:\Boxing dataset\test_frame\frame_7753.jpg
# Saved D:\Boxing dataset\test_frame\frame_7754.jpg
# Saved D:\Boxing dataset\test_frame\frame_7755.jpg
# Saved D:\Boxing dataset\test_frame\frame_7756.jpg
# Saved D:\Boxing dataset\test_frame\frame_7757.jpg
# Saved D:\Boxing dataset\test_frame\frame_7758.jpg
# Saved D:\Boxing dataset\test_frame\frame_7759.jpg
# Saved D:\Boxing dataset\test_frame\frame_7760.jpg
# Saved D:\Boxing dataset\test_frame\frame_7761.jpg
# Saved D:\Boxing dataset\test_frame\frame_7762.jpg
# Saved D:\Boxing dataset\test_frame\frame_7763.jpg
# Saved D:\Boxing dataset\test_frame\frame_7764.jpg
# Saved D:\Boxing dataset\test_frame\frame_7765.jpg
# Saved D:\Boxing dataset\test_frame\frame_7766.jpg
# Saved D:\Boxing dataset\test_frame\frame_7767.jpg
# Saved D:\Boxing dataset\test_frame\frame_7768.jpg
# Saved D:\Boxing dataset\test_frame\frame_7769.jpg
# Saved D:\Boxing dataset\test_frame\frame_7770.jpg
# Saved D:\Boxing dataset\test_frame\frame_7771.jpg
# Saved D:\Boxing dataset\test_frame\frame_7772.jpg
# Saved D:\Boxing dataset\test_frame\frame_7773.jpg
# Saved D:\Boxing dataset\test_frame\frame_7774.jpg
# Saved D:\Boxing dataset\test_frame\frame_7775.jpg
# Saved D:\Boxing dataset\test_frame\frame_7776.jpg
# Saved D:\Boxing dataset\test_frame\frame_7777.jpg
# Saved D:\Boxing dataset\test_frame\frame_7778.jpg
# Saved D:\Boxing dataset\test_frame\frame_7779.jpg
# Saved D:\Boxing dataset\test_frame\frame_7780.jpg
# Saved D:\Boxing dataset\test_frame\frame_7781.jpg
# Saved D:\Boxing dataset\test_frame\frame_7782.jpg
# Saved D:\Boxing dataset\test_frame\frame_7783.jpg
# Saved D:\Boxing dataset\test_frame\frame_7784.jpg
# Saved D:\Boxing dataset\test_frame\frame_7785.jpg
# Saved D:\Boxing dataset\test_frame\frame_7786.jpg
# Saved D:\Boxing dataset\test_frame\frame_7787.jpg
# Saved D:\Boxing dataset\test_frame\frame_7788.jpg
# Saved D:\Boxing dataset\test_frame\frame_7789.jpg
# Saved D:\Boxing dataset\test_frame\frame_7790.jpg
# Saved D:\Boxing dataset\test_frame\frame_7791.jpg
# Saved D:\Boxing dataset\test_frame\frame_7792.jpg
# Saved D:\Boxing dataset\test_frame\frame_7793.jpg
# Saved D:\Boxing dataset\test_frame\frame_7794.jpg
# Saved D:\Boxing dataset\test_frame\frame_7795.jpg
# Saved D:\Boxing dataset\test_frame\frame_7796.jpg
# Saved D:\Boxing dataset\test_frame\frame_7797.jpg
# Saved D:\Boxing dataset\test_frame\frame_7798.jpg
# Saved D:\Boxing dataset\test_frame\frame_7799.jpg
# Saved D:\Boxing dataset\test_frame\frame_7800.jpg
# Saved D:\Boxing dataset\test_frame\frame_7801.jpg
# Saved D:\Boxing dataset\test_frame\frame_7802.jpg
# Saved D:\Boxing dataset\test_frame\frame_7803.jpg
# Saved D:\Boxing dataset\test_frame\frame_7804.jpg
# Saved D:\Boxing dataset\test_frame\frame_7805.jpg
# Saved D:\Boxing dataset\test_frame\frame_7806.jpg
# Saved D:\Boxing dataset\test_frame\frame_7807.jpg
# Saved D:\Boxing dataset\test_frame\frame_7808.jpg
# Saved D:\Boxing dataset\test_frame\frame_7809.jpg
# Saved D:\Boxing dataset\test_frame\frame_7810.jpg
# Saved D:\Boxing dataset\test_frame\frame_7811.jpg
# Saved D:\Boxing dataset\test_frame\frame_7812.jpg
# Saved D:\Boxing dataset\test_frame\frame_7813.jpg
# Saved D:\Boxing dataset\test_frame\frame_7814.jpg
# Saved D:\Boxing dataset\test_frame\frame_7815.jpg
# Saved D:\Boxing dataset\test_frame\frame_7816.jpg
# Saved D:\Boxing dataset\test_frame\frame_7817.jpg
# Saved D:\Boxing dataset\test_frame\frame_7818.jpg
# Saved D:\Boxing dataset\test_frame\frame_7819.jpg
# Saved D:\Boxing dataset\test_frame\frame_7820.jpg
# Saved D:\Boxing dataset\test_frame\frame_7821.jpg
# Saved D:\Boxing dataset\test_frame\frame_7822.jpg
# Saved D:\Boxing dataset\test_frame\frame_7823.jpg
# Saved D:\Boxing dataset\test_frame\frame_7824.jpg
# Saved D:\Boxing dataset\test_frame\frame_7825.jpg
# Saved D:\Boxing dataset\test_frame\frame_7826.jpg
# Saved D:\Boxing dataset\test_frame\frame_7827.jpg
# Saved D:\Boxing dataset\test_frame\frame_7828.jpg
# Saved D:\Boxing dataset\test_frame\frame_7829.jpg
# Saved D:\Boxing dataset\test_frame\frame_7830.jpg
# Saved D:\Boxing dataset\test_frame\frame_7831.jpg
# Saved D:\Boxing dataset\test_frame\frame_7832.jpg
# Saved D:\Boxing dataset\test_frame\frame_7833.jpg
# Saved D:\Boxing dataset\test_frame\frame_7834.jpg
# Saved D:\Boxing dataset\test_frame\frame_7835.jpg
# Saved D:\Boxing dataset\test_frame\frame_7836.jpg
# Saved D:\Boxing dataset\test_frame\frame_7837.jpg
# Saved D:\Boxing dataset\test_frame\frame_7838.jpg
# Saved D:\Boxing dataset\test_frame\frame_7839.jpg
# Saved D:\Boxing dataset\test_frame\frame_7840.jpg
# Saved D:\Boxing dataset\test_frame\frame_7841.jpg
# Saved D:\Boxing dataset\test_frame\frame_7842.jpg
# Saved D:\Boxing dataset\test_frame\frame_7843.jpg
# Saved D:\Boxing dataset\test_frame\frame_7844.jpg
# Saved D:\Boxing dataset\test_frame\frame_7845.jpg
# Saved D:\Boxing dataset\test_frame\frame_7846.jpg
# Saved D:\Boxing dataset\test_frame\frame_7847.jpg
# Saved D:\Boxing dataset\test_frame\frame_7848.jpg
# Saved D:\Boxing dataset\test_frame\frame_7849.jpg
# Saved D:\Boxing dataset\test_frame\frame_7850.jpg
